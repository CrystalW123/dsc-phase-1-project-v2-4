# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name: Crystal Wanjiru
# * Student pace: full time
# * Scheduled project review date/time: 15th September 2023, 12:00 Noon
# * Instructor name: Lucille Kaleha, Diana Mongina, Nikita Njoroge,Samuel Karu
# * Blog post URL:

# %% [markdown]
# # MICROSOFT's NEW MOVIE STUDIO
#
# ## Business Understanding
#
# Microsoft wishes to join the lucrative endeavour of creating its own video content. This analysis seeks to provide actionable insights that will guide Microsoft in their desicion making.

# %% [markdown]
# ### OBJECTIVES
#
# #### Genre Analysis
# Examine the relationship between movie genres and success to determine which combinations resonate best with audiences.
#
# #### Gross Income
# Examine which type of movie brings in the most income.
#
# #### Best Studio
# Which studio performs best and why

# %% [markdown]
# ## Data Understanding

# %% [markdown]
# In the cells below I want to view the data that is present.

# %%
import pandas as pd
import sqlite3

# %%
pd.read_csv('bom.movie_gross.csv.gz')
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %% [markdown]
# The data above has the title of the movie, the studio that made the movie, the gross income from the movie both domestic and foreign and the year the movie was made.The latest data is from 2018.

# %%
pd.read_csv('rt.movie_info.tsv.gz', delimiter='\t')
# Out:
#         id                                           synopsis rating  \
# 0        1  This gritty, fast-paced, and innovative police...      R
# 1        3  New York City, not-too-distant-future: Eric Pa...      R
# 2        5  Illeana Douglas delivers a superb performance ...      R
# 3        6  Michael Douglas runs afoul of a treacherous su...      R
# 4        7                                                NaN     NR
# ...    ...                                                ...    ...
# 1555  1996  Forget terrorists or hijackers -- there's a ha...      R
# 1556  1997  The popular Saturday Night Live sketch was exp...     PG
# 1557  1998  Based on a novel by Richard Powell, when the l...      G
# 1558  1999  The Sandlot is a coming-of-age story about a g...     PG
# 1559  2000  Suspended from the force, Paris cop Hubert is ...      R
#
#                                                   genre            director  \
# ...

# %% [markdown]
# The above data set contains data on synopsis,rating,genre,writer,director,theatre date, dvd date,currency, box office, run time and studio of the movie

# %%
pd.read_csv('rt.reviews.tsv.gz', delimiter='\t', encoding='Latin')
# Out:
#          id                                             review rating   fresh  \
# 0         3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1         3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2         3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3         3  Continuing along a line introduced in last yea...    NaN   fresh
# 4         3             ... a perverse twist on neorealism...     NaN   fresh
# ...     ...                                                ...    ...     ...
# 54427  2000  The real charm of this trifle is the deadpan c...    NaN   fresh
# 54428  2000                                                NaN    1/5  rotten
# 54429  2000                                                NaN    2/5  rotten
# 54430  2000                                                NaN  2.5/5  rotten
# 54431  2000                                                NaN    3/5   fresh
#
# ...

# %% [markdown]
# This data contains reviews of some movies, with the critics and publisher and date published

# %%
pd.read_csv('tmdb.movies.csv.gz', index_col=0)
# Out:
#                  genre_ids      id original_language  \
# 0          [12, 14, 10751]   12444                en
# 1      [14, 12, 16, 10751]   10191                en
# 2            [12, 28, 878]   10138                en
# 3          [16, 35, 10751]     862                en
# 4            [28, 878, 12]   27205                en
# ...                    ...     ...               ...
# 26512             [27, 18]  488143                en
# 26513             [18, 53]  485975                en
# 26514         [14, 28, 12]  381231                en
# 26515      [10751, 12, 28]  366854                en
# 26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                          How to Train Your Dragon      28.734   2010-03-26
# 2                                        Iron Man 2      28.515   2010-05-07
# ...

# %% [markdown]
# The data contains data on the genre, language, title, popularity, release date,vote count and vot average of the movie

# %%
pd.read_csv('tn.movie_budgets.csv.gz')
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# ...

# %% [markdown]
# The above table shows the release_date, movie, production_budget, domestic_gross and worldwide combined gross for each movie

# %%
conn= sqlite3.connect('im.db/im.db')
pd.read_sql("""
SELECT *
FROM sqlite_master
""",conn)
# Out:
#     type           name       tbl_name  rootpage  \
# 0  table   movie_basics   movie_basics         2
# 1  table      directors      directors         3
# 2  table      known_for      known_for         4
# 3  table     movie_akas     movie_akas         5
# 4  table  movie_ratings  movie_ratings         6
# 5  table        persons        persons         7
# 6  table     principals     principals         8
# 7  table        writers        writers         9
#
#                                                  sql
# 0  CREATE TABLE "movie_basics" (\n"movie_id" TEXT...
# 1  CREATE TABLE "directors" (\n"movie_id" TEXT,\n...
# 2  CREATE TABLE "known_for" (\n"person_id" TEXT,\...
# 3  CREATE TABLE "movie_akas" (\n"movie_id" TEXT,\...
# 4  CREATE TABLE "movie_ratings" (\n"movie_id" TEX...
# 5  CREATE TABLE "persons" (\n"person_id" TEXT,\n ...
# 6  CREATE TABLE "principals" (\n"movie_id" TEXT,\...
# 7  CREATE TABLE "writers" (\n"movie_id" TEXT,\n  ...

# %%
q1="""
SELECT *
FROM movie_basics;
"""
pd.read_sql(q1,conn)
# Out:
#          movie_id                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %%
q2="""
SELECT *
FROM movie_ratings;
"""
pd.read_sql(q2,conn)
# Out:
#          movie_id  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73856 rows x 3 columns]

# %% [markdown]
# Having a look at the various data I have written off the 'tmdb.movies.csv.gz' data and have decided for my objectives the dataset will not be of any use

# %% [markdown]
# ### A close look at the data I have
# I want to view the tables individualy and see what I am working with

# %%
def df_info(df):
    print(df.info())

# %%
bom = pd.read_csv('bom.movie_gross.csv.gz')
movie_synopsis = pd.read_csv('rt.movie_info.tsv.gz', delimiter='\t')
movie_reviews = pd.read_csv('rt.reviews.tsv.gz', delimiter='\t', encoding='Latin')
movie_budgets = pd.read_csv('tn.movie_budgets.csv.gz')
movie_basics = pd.read_sql(q1,conn)
movie_ratings = pd.read_sql(q2,conn)

# %%
df_info(bom)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB
# None

# %%
df_info(movie_synopsis)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1560 entries, 0 to 1559
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1560 non-null   int64
#  1   synopsis      1498 non-null   object
#  2   rating        1557 non-null   object
#  3   genre         1552 non-null   object
#  4   director      1361 non-null   object
#  5   writer        1111 non-null   object
#  6   theater_date  1201 non-null   object
#  7   dvd_date      1201 non-null   object
#  8   currency      340 non-null    object
#  9   box_office    340 non-null    object
#  10  runtime       1530 non-null   object
#  11  studio        494 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 146.4+ KB
# None

# %%
df_info(movie_budgets)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB
# None

# %%
df_info(movie_basics)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   movie_id         146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146123 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB
# None

# %%
df_info(movie_ratings)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   movie_id       73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB
# None

# %%
df_info(movie_reviews)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54432 entries, 0 to 54431
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          54432 non-null  int64
#  1   review      48869 non-null  object
#  2   rating      40915 non-null  object
#  3   fresh       54432 non-null  object
#  4   critic      51710 non-null  object
#  5   top_critic  54432 non-null  int64
#  6   publisher   54123 non-null  object
#  7   date        54432 non-null  object
# dtypes: int64(2), object(6)
# memory usage: 3.3+ MB
# None

# %% [markdown]
# The datasets that I will take the most consideration of are the bom ('bom.movie_gross.csv.gz') data and the sql database especially the movie_basic and movie_ratings tables

# %% [markdown]
# I want to find out more about the data I will be working with

# %%
def shape(df):
    print(df.shape)

# %%
shape(bom)
# Out:
# (3387, 5)

# %%
def describe(df):
    df.describe()
    return df.describe()

# %%
def value_count(dfSeries):
    dfSeries.value_counts()
    return dfSeries.value_counts()

# %%
def unique_count(dfSeries):
    dfSeries.unique()
    return dfSeries.unique()

# %%
def null_values(df):
    df.isna().any()
    return df.isna().any()

# %%
def num_of_null(df):
    df.isna().sum()
    return df.isna().sum()

# %%
bom.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %% [markdown]
# From the info we saw something interesting with the foreign_gross data its type is object meaning it is a string, but from the table those look like numbers and also it is expected that the gross would be integers or floats.

# %%
#Just a preview of the column
bom['foreign_gross'].head()
# Out:
# 0    652000000
# 1    691300000
# 2    664300000
# 3    535700000
# 4    513900000
# Name: foreign_gross, dtype: object

# %%
#Change the foreign_gross column into integers
bom['foreign_gross'] = bom['foreign_gross'].str.replace(',', '').astype('float')

# %%
null_values(bom)
# Out:
# title             False
# studio             True
# domestic_gross     True
# foreign_gross      True
# year              False
# dtype: bool

# %% [markdown]
# From the 'bom' DataFrame we have missing data in the studio,domestic_gross and foreign_gross columns

# %%
#Let us find out how many missing values in each column
num_of_null(bom)
# Out:
# title                0
# studio               5
# domestic_gross      28
# foreign_gross     1350
# year                 0
# dtype: int64

# %%
#And the percentage of missing values in each column
print(num_of_null(bom)/len(bom['title'])*100)
# Out:
# title              0.000000
# studio             0.147623
# domestic_gross     0.826690
# foreign_gross     39.858282
# year               0.000000
# dtype: float64

# %% [markdown]
# The foreign_gross column has the highest percentage of missing values, followed by the domestic_gross column then the studio column which has the lowest percentage. Now to deal with the missing values. Because I do not want to lose the data I prefer to replace the missing in the foreign_gross column with the median of that column because deleting it will lead to a huge loss of data, for the domestic gross I would also fill the null values with median while for the studio I would rather delete the rows since the missing values are not many

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
bom['foreign_gross'].head()
# Out:
# 0    652000000.0
# 1    691300000.0
# 2    664300000.0
# 3    535700000.0
# 4    513900000.0
# Name: foreign_gross, dtype: float64

# %%
fig, ax = plt.subplots(figsize = [15,8])
ax.hist(bom['foreign_gross'], bins = 80, color= 'green')
ax.set_xlabel('foreign_gross')
ax.set_ylabel('Frequency')
ax.axvline(bom['foreign_gross'].mean(), color = 'black', linestyle= 'dashed');
print(bom['foreign_gross'].mean())
print(bom['foreign_gross'].median())
# Out:
# 74872810.15046637
# 18700000.0

# %%
#Just to view the effect of replacing with the median
bom_median_foreign = bom['foreign_gross'].fillna(bom['foreign_gross'].median())
bom_median_foreign
# Out:
# 0       652000000.0
# 1       691300000.0
# 2       664300000.0
# 3       535700000.0
# 4       513900000.0
#            ...
# 3382     18700000.0
# 3383     18700000.0
# 3384     18700000.0
# 3385     18700000.0
# 3386     18700000.0
# Name: foreign_gross, Length: 3387, dtype: float64

# %%
fig, ax = plt.subplots(figsize = [15,8])
ax.hist(bom_median_foreign, bins = 80, color= 'green')
ax.set_xlabel('foreign_gross')
ax.set_ylabel('Frequency')
ax.axvline(bom_median_foreign.mean(), color = 'black', linestyle= 'dashed');
print(bom_median_foreign.mean())
print(bom_median_foreign.median())
# Out:
# 52483293.261440806
# 18700000.0

# %%
bom_mean_foreign= bom['foreign_gross'].fillna(bom['foreign_gross'].mean())

# %%
fig, ax = plt.subplots(figsize = [15,8])
ax.hist(bom_mean_foreign, bins = 80, color= 'green')
ax.set_xlabel('foreign_gross')
ax.set_ylabel('Frequency')
ax.axvline(bom_mean_foreign.mean(), color = 'black', linestyle= 'dashed');
print(bom_mean_foreign.mean())
print(bom_mean_foreign.median())
# Out:
# 74872810.15046637
# 74872810.15046637

# %%
#Now to fill the actual dataset with the median values(since our data was skewed median is less sensitive to outliers)
bom['foreign_gross'] = bom['foreign_gross'].fillna(bom['foreign_gross'].median())
num_of_null(bom)
# Out:
# title              0
# studio             5
# domestic_gross    28
# foreign_gross      0
# year               0
# dtype: int64

# %%
#Now the domestic_gross
fig, ax = plt.subplots(figsize = [15,8])
ax.hist(bom['domestic_gross'], bins = 80, color= 'green')
ax.set_xlabel('domestic_gross')
ax.set_ylabel('Frequency')
ax.axvline(bom['domestic_gross'].mean(), color = 'black', linestyle= 'dashed');
print(bom['domestic_gross'].mean())
print(bom['domestic_gross'].median())
# Out:
# 28745845.06698422
# 1400000.0

# %%
bom['domestic_gross']= bom['domestic_gross'].fillna(bom['domestic_gross'].median())
num_of_null(bom)
# Out:
# title             0
# studio            5
# domestic_gross    0
# foreign_gross     0
# year              0
# dtype: int64

# %%
bom = bom.dropna()
num_of_null(bom)
# Out:
# title             0
# studio            0
# domestic_gross    0
# foreign_gross     0
# year              0
# dtype: int64

# %%
shape(bom)
# Out:
# (3382, 5)

# %% [markdown]
# We are less 5 rows from the dataframe but have delt with the missing values and can continue to inspect the data for any other anomalies

# %%
def duplicates(df):
    duplicates = df[df.duplicated()]
    print(len(duplicates))
    return duplicates.head()

# %%
duplicates(bom)
# Out:
# 0
# Empty DataFrame
# Columns: [title, studio, domestic_gross, foreign_gross, year]
# Index: []

# %% [markdown]
# There are no duplicates in this dataframe and thus we can continue to the other data frames

# %%
#let us remember the data
movie_basics.head()
# Out:
#     movie_id                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
shape(movie_basics)
# Out:
# (146144, 6)

# %%
df_info(movie_basics)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   movie_id         146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146123 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB
# None

# %% [markdown]
# The format seems to be ok, I want to now work on the missing values, see if there is any and deal with them and also any other anomalies

# %%
null_values(movie_basics)
# Out:
# movie_id           False
# primary_title      False
# original_title      True
# start_year         False
# runtime_minutes     True
# genres              True
# dtype: bool

# %% [markdown]
# Looks like we have some missing values, following the same procedure as the data before

# %%
num_of_null(movie_basics)
# Out:
# movie_id               0
# primary_title          0
# original_title        21
# start_year             0
# runtime_minutes    31739
# genres              5408
# dtype: int64

# %%
print(num_of_null(movie_basics)/len(movie_basics['movie_id'])*100)
# Out:
# movie_id            0.000000
# primary_title       0.000000
# original_title      0.014369
# start_year          0.000000
# runtime_minutes    21.717621
# genres              3.700460
# dtype: float64

# %% [markdown]
# The runtime of movies has most of the missing data, followed by genres then lastly original_title, to deal with the runtime I will replace the values, similar to genre but will drop the rows that do not have the original_title.

# %%
print(movie_basics['runtime_minutes'].mean())
print(movie_basics['runtime_minutes'].median())
print(movie_basics['runtime_minutes'].std())
# Out:
# 86.18724706088021
# 87.0
# 166.36059015397228

# %%
df_movie_basics = movie_basics['runtime_minutes'].fillna(movie_basics['runtime_minutes'].median())
print(df_movie_basics.mean())
print(df_movie_basics.median())
print(df_movie_basics.std())
# Out:
# 86.36375766367418
# 87.0
# 147.1916499195228

# %% [markdown]
# Not much of a variation if we choose to replace with the median

# %%
df_movie_basicsm = movie_basics['runtime_minutes'].fillna(movie_basics['runtime_minutes'].mean())
print(df_movie_basicsm.mean())
print(df_movie_basicsm.median())
print(df_movie_basicsm.std())
# Out:
# 86.18724706088021
# 86.18724706088021
# 147.19126842902267

# %% [markdown]
# Both the mean and median are good options

# %%
movie_basics['runtime_minutes'] = movie_basics['runtime_minutes'].fillna(movie_basics['runtime_minutes'].median())
num_of_null(movie_basics)
# Out:
# movie_id              0
# primary_title         0
# original_title       21
# start_year            0
# runtime_minutes       0
# genres             5408
# dtype: int64

# %%
#We move to genres
unique_count(movie_basics['genres'])
print(len(unique_count(movie_basics['genres'])))
# Out:
# 1086

# %%
value_count(movie_basics['genres'])
# Out:
# Documentary                 32185
# Drama                       21486
# Comedy                       9177
# Horror                       4372
# Comedy,Drama                 3519
#                             ...
# Mystery,Thriller,War            1
# Action,Crime,Western            1
# Crime,Music                     1
# Crime,Documentary,Horror        1
# Family,Sci-Fi,Thriller          1
# Name: genres, Length: 1085, dtype: int64

# %%
movie_basics['genres'] = movie_basics['genres'].fillna(movie_basics['genres'].mode()[0])
num_of_null(movie_basics)
# Out:
# movie_id            0
# primary_title       0
# original_title     21
# start_year          0
# runtime_minutes     0
# genres              0
# dtype: int64

# %%
movie_basics= movie_basics.dropna()
num_of_null(movie_basics)
# Out:
# movie_id           0
# primary_title      0
# original_title     0
# start_year         0
# runtime_minutes    0
# genres             0
# dtype: int64

# %%
shape(movie_basics)
# Out:
# (146123, 6)

# %% [markdown]
# We are less 21 rows but have dealt with the missing data

# %%
duplicates(movie_basics)
# Out:
# 0
# Empty DataFrame
# Columns: [movie_id, primary_title, original_title, start_year, runtime_minutes, genres]
# Index: []

# %% [markdown]
# The data has no duplicates

# %%
#The next table is the movie_ratings
df_info(movie_ratings)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   movie_id       73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB
# None

# %%
#It looks like this data has no missing values but to be sure
null_values(movie_ratings)
# Out:
# movie_id         False
# averagerating    False
# numvotes         False
# dtype: bool

# %%
#let us look for duplicates
duplicates(movie_ratings)
# Out:
# 0
# Empty DataFrame
# Columns: [movie_id, averagerating, numvotes]
# Index: []

# %% [markdown]
# No duplicates, maybe placeholder values

# %%
value_count(movie_ratings['averagerating'])
# Out:
# 7.0     2262
# 6.6     2251
# 7.2     2249
# 6.8     2239
# 6.5     2221
#         ...
# 9.6       18
# 10.0      16
# 9.8       15
# 9.7       12
# 9.9        5
# Name: averagerating, Length: 91, dtype: int64

# %%
value_count(movie_ratings['numvotes'])
# Out:
# 6        2875
# 5        2699
# 7        2476
# 8        2167
# 9        1929
#          ...
# 18286       1
# 16289       1
# 1958        1
# 4007        1
# 4098        1
# Name: numvotes, Length: 7349, dtype: int64

# %% [markdown]
# It does not look like there is anything wrong with the data

# %%
movie_budgets.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
#Just a preview of transforming the data to float
movie_prod= movie_budgets['production_budget'].str.replace('$', '').str.replace(',', '').astype(float)
movie_prod
# Out:
# 0       425000000.0
# 1       410600000.0
# 2       350000000.0
# 3       330600000.0
# 4       317000000.0
#            ...
# 5777         7000.0
# 5778         6000.0
# 5779         5000.0
# 5780         1400.0
# 5781         1100.0
# Name: production_budget, Length: 5782, dtype: float64

# %%
#Now to do it on the data set
columns_to_convert = ['production_budget', 'domestic_gross','worldwide_gross']
for col in columns_to_convert:
    movie_budgets[col] = movie_budgets[col].str.replace('$', '').str.replace(',', '').astype(float)
movie_budgets.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross  worldwide_gross
# 0        425000000.0     760507625.0     2.776345e+09
# 1        410600000.0     241063875.0     1.045664e+09
# 2        350000000.0      42762350.0     1.497624e+08
# 3        330600000.0     459005868.0     1.403014e+09
# 4        317000000.0     620181382.0     1.316722e+09

# %%
num_of_null(movie_budgets)
# Out:
# id                   0
# release_date         0
# movie                0
# production_budget    0
# domestic_gross       0
# worldwide_gross      0
# dtype: int64

# %% [markdown]
# The data has no missing values

# %%
duplicates(movie_budgets)
# Out:
# 0
# Empty DataFrame
# Columns: [id, release_date, movie, production_budget, domestic_gross, worldwide_gross]
# Index: []

# %% [markdown]
# And no duplicates

# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS EDA
# Now to do some data analysis I will first try to answer the question which film is the most successful and will use the Box Office Mojo Data to see how much gross income the highest movies had and which movies they were.

# %%
#Preview of my data
bom.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#    foreign_gross  year
# 0    652000000.0  2010
# 1    691300000.0  2010
# 2    664300000.0  2010
# 3    535700000.0  2010
# 4    513900000.0  2010

# %%
#I will first add the domestic gross and foreign gross to get the total income
bom['Total_gross'] = bom['domestic_gross'] + bom['foreign_gross']
bom.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#    foreign_gross  year   Total_gross
# 0    652000000.0  2010  1.067000e+09
# 1    691300000.0  2010  1.025500e+09
# 2    664300000.0  2010  9.603000e+08
# 3    535700000.0  2010  8.283000e+08
# 4    513900000.0  2010  7.526000e+08

# %%
#Now to order by the Total_gross in descending order
sorted_bom = bom.sort_values(by='Total_gross',ascending = False)
sorted_bom.head()
# Out:
#                                             title studio  domestic_gross  \
# 727                         Marvel's The Avengers     BV     623400000.0
# 1875                      Avengers: Age of Ultron     BV     459000000.0
# 3080                                Black Panther     BV     700100000.0
# 328   Harry Potter and the Deathly Hallows Part 2     WB     381000000.0
# 2758                     Star Wars: The Last Jedi     BV     620200000.0
#
#       foreign_gross  year   Total_gross
# 727     895500000.0  2012  1.518900e+09
# 1875    946400000.0  2015  1.405400e+09
# 3080    646900000.0  2018  1.347000e+09
# 328     960500000.0  2011  1.341500e+09
# 2758    712400000.0  2017  1.332600e+09

# %% [markdown]
# The movie that has the most gross income is the 'Marvel's The Avengers' movie with a total gross of $1518900000 followed by the Avengers:Age of Ultron then Black Panther.

# %%
#To see this more clearly we can represent the above result in bar chart
fig,ax = plt.subplots(figsize=(15,8))
c = ['red', 'yellow', 'black', 'blue','orange']
ax.bar(x = sorted_bom[:5]['title'], height=sorted_bom[:5]['Total_gross'], color = c)
ax.set_ylabel('Total_gross')
ax.set_title('Top Five Movies')
plt.xticks(rotation=90);
plt.savefig("C:/Users/Crystal/Documents/Course-Materials/Section-1/Projectimages/Images.pdf")

# %%
Path_to_image = "C:/Users/Crystal/Documents/Course-Materials/Section-1/Projectimages/Images.pdf"

# %%
#Checking with the movie_bugdets table which also shows the gross income
movie_budgets.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross  worldwide_gross
# 0        425000000.0     760507625.0     2.776345e+09
# 1        410600000.0     241063875.0     1.045664e+09
# 2        350000000.0      42762350.0     1.497624e+08
# 3        330600000.0     459005868.0     1.403014e+09
# 4        317000000.0     620181382.0     1.316722e+09

# %%
movie_budgets['Profit']= movie_budgets['worldwide_gross'] - movie_budgets['production_budget']
movie_budgets.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross  worldwide_gross        Profit
# 0        425000000.0     760507625.0     2.776345e+09  2.351345e+09
# 1        410600000.0     241063875.0     1.045664e+09  6.350639e+08
# 2        350000000.0      42762350.0     1.497624e+08 -2.002376e+08
# 3        330600000.0     459005868.0     1.403014e+09  1.072414e+09
# 4        317000000.0     620181382.0     1.316722e+09  9.997217e+08

# %%
sorted_budget = movie_budgets.sort_values(by='Profit', ascending = False)
sorted_budget.head()
# Out:
#     id  release_date                                 movie  production_budget  \
# 0    1  Dec 18, 2009                                Avatar        425000000.0
# 42  43  Dec 19, 1997                               Titanic        200000000.0
# 6    7  Apr 27, 2018                Avengers: Infinity War        300000000.0
# 5    6  Dec 18, 2015  Star Wars Ep. VII: The Force Awakens        306000000.0
# 33  34  Jun 12, 2015                        Jurassic World        215000000.0
#
#     domestic_gross  worldwide_gross        Profit
# 0      760507625.0     2.776345e+09  2.351345e+09
# 42     659363944.0     2.208208e+09  2.008208e+09
# 6      678815482.0     2.048134e+09  1.748134e+09
# 5      936662225.0     2.053311e+09  1.747311e+09
# 33     652270625.0     1.648855e+09  1.433855e+09

# %% [markdown]
# From both tables the budgets table and the box office tables there is an Avengers movie and a Star Wars movie, these are the type of movies that gain the most profit and produce the highest income.

# %% [markdown]
# The above was over the years data, and as we have seen Avengers movie and Star Wars being the most recent were in the list as well

# %%
#Now to check which is the succesful in the recent years, our most recent year was 2018 from the bom table
bom_sorted_year= sorted_bom.loc[sorted_bom['year']>= 2015] #We will check from the year 2015
bom_sorted_year.head(10)
# Out:
#                                title studio  domestic_gross  foreign_gross  \
# 1875         Avengers: Age of Ultron     BV     459000000.0    946400000.0
# 3080                   Black Panther     BV     700100000.0    646900000.0
# 2758        Star Wars: The Last Jedi     BV     620200000.0    712400000.0
# 3081  Jurassic World: Fallen Kingdom   Uni.     417700000.0    891800000.0
# 2759     Beauty and the Beast (2017)     BV     504000000.0    759500000.0
# 3082                   Incredibles 2     BV     608600000.0    634200000.0
# 1876                         Minions   Uni.     336000000.0    823400000.0
# 2322      Captain America: Civil War     BV     408100000.0    745200000.0
# 3083                         Aquaman     WB     335100000.0    812700000.0
# 2323    Rogue One: A Star Wars Story     BV     532200000.0    523900000.0
#
#       year   Total_gross
# 1875  2015  1.405400e+09
# 3080  2018  1.347000e+09
# 2758  2017  1.332600e+09
# 3081  2018  1.309500e+09
# ...

# %%
#Let us plot a bar chart to show this, we will plot the 10 most successful titles in the recent years
fig,ax = plt.subplots(figsize=(13,8))
ax.bar(x=bom_sorted_year['title'][:10], height=bom_sorted_year['Total_gross'][:10], color='red')
ax.set_title('Top 10 Most Succesful Films from 2015')
ax.set_xlabel('Films')
ax.set_ylabel('Total Gross in Million Dollars')
plt.xticks(rotation=90);

# %% [markdown]
# Still from above Avengers movie manages to top the list, recently people seem to like the these types of movies and from the list you will find that the studio that has produced most of them is the BV studio which we will investigate next. But it seems like they found what people like watching. The above was a guide as to what people like to watch.

# %% [markdown]
# ### The second objective will investigate the studios
# Which is the best studio looking at the gross income from the Box Office Data

# %%
bom.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#    foreign_gross  year   Total_gross
# 0    652000000.0  2010  1.067000e+09
# 1    691300000.0  2010  1.025500e+09
# 2    664300000.0  2010  9.603000e+08
# 3    535700000.0  2010  8.283000e+08
# 4    513900000.0  2010  7.526000e+08

# %%
bom['studio'].value_counts()
# Out:
# IFC          166
# Uni.         147
# WB           140
# Magn.        136
# Fox          136
#             ...
# Spanglish      1
# DR             1
# Rocket         1
# RLJ            1
# Indic.         1
# Name: studio, Length: 257, dtype: int64

# %%
grouped_studio= bom.groupby('studio').sum()
grouped_studio.head()
# Out:
#         domestic_gross  foreign_gross   year   Total_gross
# studio
# 3D           6100000.0      9900000.0   2010  1.600000e+07
# A23           164200.0     37400000.0   4024  3.756420e+07
# A24        324194200.0    799462200.0  98754  1.123656e+09
# ADC           248200.0     37400000.0   4032  3.764820e+07
# AF           2142900.0     78300000.0  12080  8.044290e+07

# %%
shape(grouped_studio)
# Out:
# (257, 4)

# %%
sorted_grouped_studio = grouped_studio.sort_values(by='Total_gross', ascending=False)
sorted_grouped_studio.head()
# Out:
#         domestic_gross  foreign_gross    year   Total_gross
# studio
# BV        1.841903e+10   2.583125e+10  213451  4.425028e+10
# Fox       1.094950e+10   2.009327e+10  273882  3.104277e+10
# WB        1.216805e+10   1.885490e+10  281941  3.102295e+10
# Uni.      1.290239e+10   1.691087e+10  296082  2.981326e+10
# Sony      8.461083e+09   1.402015e+10  221575  2.248124e+10

# %% [markdown]
# It seems that the BV studio has the highest Total Gross, but this could be because it has produced a large number of movies or m the type of movies it is producing. So the next question is, it it the type of movies or the number of movies it is producing or a different factor entirely but first let us have a bar chart to represent the studios, the first five studios and the last five studios.

# %%
fig,ax = plt.subplots(ncols = 2,figsize=(13,8))
ax[0].bar(x = sorted_grouped_studio[:5].index,height=sorted_grouped_studio[:5]['Total_gross'], color='red')
ax[0].set_ylabel('Total_gross')
ax[0].set_title('Top Five Studios')
ax[1].bar(x=sorted_grouped_studio[-5:].index,height=sorted_grouped_studio[-5:]['Total_gross'], color='blue')
ax[1].set_ylabel('Total_gross')
ax[1].set_title('Last Five Studios');
plt.savefig(Path_to_image)

# %% [markdown]
# BV is doing way better than expected compared to the other studios, now let us see if it is caused by the number of movies it is producing

# %%
fig,ax = plt.subplots(figsize=(15,8))
value_counts = bom["studio"].value_counts()
top_5_counts = value_counts.iloc[:5]
ax.bar(top_5_counts.index,top_5_counts.values, color= 'orange')
ax.set_ylabel('Counts')
ax.set_title('Top Five Studios According to Movies Produced');

# %% [markdown]
# As it is shown in the graph BV studio is not even in the top five and so for BV studio it is not the number of movies produced because even some of the studios that are in the top 5 are not in the top five with highest income that is IFC and Magn, though some like Uni, WB and Fox are, this does not clearly say whether the number of movies affects the gross income.

# %% [markdown]
# Let us get the count of each and find the correlation between the count and the gross income

# %%
bom.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#    foreign_gross  year   Total_gross
# 0    652000000.0  2010  1.067000e+09
# 1    691300000.0  2010  1.025500e+09
# 2    664300000.0  2010  9.603000e+08
# 3    535700000.0  2010  8.283000e+08
# 4    513900000.0  2010  7.526000e+08

# %%
grouped_studio_count= bom.groupby('studio').count()
grouped_studio_count.head()
# Out:
#         title  domestic_gross  foreign_gross  year  Total_gross
# studio
# 3D          1               1              1     1            1
# A23         2               2              2     2            2
# A24        49              49             49    49           49
# ADC         2               2              2     2            2
# AF          6               6              6     6            6

# %%
grouped_studio['Count']= grouped_studio_count['title']
grouped_studio.head()
# Out:
#         domestic_gross  foreign_gross   year   Total_gross  Count
# studio
# 3D           6100000.0      9900000.0   2010  1.600000e+07      1
# A23           164200.0     37400000.0   4024  3.756420e+07      2
# A24        324194200.0    799462200.0  98754  1.123656e+09     49
# ADC           248200.0     37400000.0   4032  3.764820e+07      2
# AF           2142900.0     78300000.0  12080  8.044290e+07      6

# %% [markdown]
# From the table above we can check the correlation

# %%
correlation = grouped_studio['Total_gross'].corr(grouped_studio['Count'])
print(correlation)
# Out:
# 0.6957109365459601

# %% [markdown]
# It seems there is a moderate positive correlation between the two as the count of movies increases so does the Total_gross income. Let us confirm this using a scatter plot

# %%
fig, ax = plt.subplots(figsize=(10, 8))
ax.scatter(x=grouped_studio['Total_gross'],y=grouped_studio['Count'],c = 'r')
ax.set_xlabel("Total gross Income")
ax.set_ylabel("Number of movies")
ax.set_title("Total gross Income Vs Number of movies");

# %% [markdown]
# There is only a slight relationship between Number of movies and the gross income. From this we can also conclude that the BV studio apart from making a significant number of movies has other factors that contribute to its success and so it is not only the number of movies that count to be successful in the industry.

# %% [markdown]
# Let us investigate another factor from the data we have we can get how much a studio spent in production if we merge the bom table and the movie_budgets using the title/movie column, we will not get every movie but will get a significant number.

# %%
movie_budgets_renamed= movie_budgets.rename(columns={'movie': 'title'})
movie_budgets_renamed.head()
# Out:
#    id  release_date                                        title  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross  worldwide_gross        Profit
# 0        425000000.0     760507625.0     2.776345e+09  2.351345e+09
# 1        410600000.0     241063875.0     1.045664e+09  6.350639e+08
# 2        350000000.0      42762350.0     1.497624e+08 -2.002376e+08
# 3        330600000.0     459005868.0     1.403014e+09  1.072414e+09
# 4        317000000.0     620181382.0     1.316722e+09  9.997217e+08

# %%
bom_movie_budgets = bom.merge(movie_budgets_renamed, on='title',how='inner')
bom_movie_budgets
# Out:
#                            title studio  domestic_gross_x  foreign_gross  \
# 0                    Toy Story 3     BV       415000000.0    652000000.0
# 1                      Inception     WB       292600000.0    535700000.0
# 2            Shrek Forever After   P/DW       238700000.0    513900000.0
# 3     The Twilight Saga: Eclipse   Sum.       300500000.0    398000000.0
# 4                     Iron Man 2   Par.       312400000.0    311500000.0
# ...                          ...    ...               ...            ...
# 1241                       Gotti     VE         4300000.0     18700000.0
# 1242                 Ben is Back  RAtt.         3700000.0     18700000.0
# 1243  Bilal: A New Breed of Hero     VE          491000.0      1700000.0
# 1244                       Mandy    RLJ         1200000.0     18700000.0
# 1245                Lean on Pete    A24         1200000.0     18700000.0
#
#       year   Total_gross   id  release_date  production_budget  \
# ...

# %%
bom_movie_budgetsgrouped = bom_movie_budgets.groupby('studio').mean()
bom_movie_budgetsgrouped.head()
# Out:
#         domestic_gross_x  foreign_gross        year   Total_gross         id  \
# studio
# 3D          6.100000e+06   9.900000e+06  2010.00000  1.600000e+07  31.000000
# A24         1.141252e+07   1.644286e+07  2015.52381  2.785538e+07  48.095238
# ALP         2.800000e+03   1.870000e+07  2011.00000  1.870280e+07  52.000000
# ATO         1.000000e+06   4.070000e+04  2010.00000  1.040700e+06  32.000000
# Affirm      1.170000e+07   2.820000e+06  2017.50000  1.452000e+07  53.500000
#
#         production_budget  domestic_gross_y  worldwide_gross        Profit
# studio
# 3D           5.000000e+06      6.096582e+06     1.651520e+07  1.151520e+07
# A24          6.814286e+06      1.141401e+07     1.904788e+07  1.223359e+07
# ALP          2.600000e+07      4.247200e+04     2.923959e+06 -2.307604e+07
# ATO          1.250000e+07      2.039869e+06     2.272186e+06 -1.022781e+07
# Affirm       3.500000e+06      1.167510e+07     1.573575e+07  1.223575e+07

# %%
#First 10 movie studios that had a high budget
bom_movie_sorted=bom_movie_budgetsgrouped.sort_values(by='production_budget', ascending=False)
bom_movie_sorted.head(10)
# Out:
#          domestic_gross_x  foreign_gross         year   Total_gross  \
# studio
# P/DW         1.682900e+08   3.393600e+08  2010.900000  5.076500e+08
# BV           1.795403e+08   2.659158e+08  2013.902778  4.454561e+08
# WB           9.011667e+07   1.298089e+08  2013.715686  2.199255e+08
# Fox          8.460364e+07   1.587412e+08  2013.727273  2.433449e+08
# NM           6.190000e+05   3.840000e+07  2010.000000  3.901900e+07
# Sony         9.656757e+07   1.435194e+08  2013.567568  2.400870e+08
# Par.         8.160946e+07   1.158658e+08  2013.797297  1.974752e+08
# WB (NL)      9.237027e+07   1.406784e+08  2014.162162  2.330486e+08
# Uni.         9.205759e+07   1.160510e+08  2013.914530  2.081086e+08
# LG/S         4.975484e+07   7.960626e+07  2014.225806  1.293611e+08
#
#                 id  production_budget  domestic_gross_y  worldwide_gross  \
# studio
# P/DW     43.900000       1.334000e+08      1.682915e+08     5.078028e+08
# ...

# %% [markdown]
# As seen BV together with the top five highest gross appear in the list with the highest average production budget, these studios seem to spend a lot in the production of their movies and this could be the reason as to why the movies sell so well.

# %%
bom_movie_budgets_count = bom_movie_budgets.groupby('studio').count()
bom_movie_budgets_count.head()
# Out:
#         title  domestic_gross_x  foreign_gross  year  Total_gross  id  \
# studio
# 3D          1                 1              1     1            1   1
# A24        21                21             21    21           21  21
# ALP         1                 1              1     1            1   1
# ATO         1                 1              1     1            1   1
# Affirm      2                 2              2     2            2   2
#
#         release_date  production_budget  domestic_gross_y  worldwide_gross  \
# studio
# 3D                 1                  1                 1                1
# A24               21                 21                21               21
# ALP                1                  1                 1                1
# ATO                1                  1                 1                1
# Affirm             2                  2                 2                2
#
#         Profit
# studio
# 3D           1
# A24         21
# ALP          1
# ...

# %%
bom_movie_budgetsgrouped['Count'] = bom_movie_budgets_count['title']
bom_movie_budgetsgrouped.head()
# Out:
#         domestic_gross_x  foreign_gross        year   Total_gross         id  \
# studio
# 3D          6.100000e+06   9.900000e+06  2010.00000  1.600000e+07  31.000000
# A24         1.141252e+07   1.644286e+07  2015.52381  2.785538e+07  48.095238
# ALP         2.800000e+03   1.870000e+07  2011.00000  1.870280e+07  52.000000
# ATO         1.000000e+06   4.070000e+04  2010.00000  1.040700e+06  32.000000
# Affirm      1.170000e+07   2.820000e+06  2017.50000  1.452000e+07  53.500000
#
#         production_budget  domestic_gross_y  worldwide_gross        Profit  \
# studio
# 3D           5.000000e+06      6.096582e+06     1.651520e+07  1.151520e+07
# A24          6.814286e+06      1.141401e+07     1.904788e+07  1.223359e+07
# ALP          2.600000e+07      4.247200e+04     2.923959e+06 -2.307604e+07
# ATO          1.250000e+07      2.039869e+06     2.272186e+06 -1.022781e+07
# Affirm       3.500000e+06      1.167510e+07     1.573575e+07  1.223575e+07
#
#         Count
# studio
# ...

# %%
#Let us see if average production_budget correlates with the average Profit
correlation2 = bom_movie_budgetsgrouped['production_budget'].corr(bom_movie_budgetsgrouped['Profit'])
print(correlation2)
# Out:
# 0.8210296139686298

# %% [markdown]
# Looks like the values are highly positively correlated as the production_budget increases so does the Profit

# %%
fig, ax = plt.subplots(figsize=(10, 8))
ax.scatter(x=bom_movie_budgetsgrouped['production_budget'],y=bom_movie_budgetsgrouped['Profit'])
ax.set_xlabel("Average production budget")
ax.set_ylabel("Profit")
ax.set_title("Production_budget Vs Profit");

# %% [markdown]
# Looks like there is correlation between the two, and so we have investigated the studio and the final conclusion is that both the number of movies and the amount of money spent on production have similar trend when compared to the gross income received.Meaning that the amount of movies you make and also the amount of money you spend on your actors the production team and the film making goes hand in hand with the gross income you receive. Not to say that it affects the gross income we will need regression analysis to see the factors that affect gross income but from the scatter plot and our calculation as the studios spend more on the production and as the number of movies increases there is an increase in the gross income.

# %% [markdown]
# ### The third objective what genre is the most watched
# I will now investigate the genre of movie that is trendy, for this one I will use the movie_basics, bom and the movie_ratings datasets

# %%
#remind myself how the data looks like
movie_basics.head()
# Out:
#     movie_id                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018             87.0          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
movie_ratings.head()
# Out:
#      movie_id  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
#These two data sets can be merged as one
moviebasics_ratings = movie_basics.merge(movie_ratings, on='movie_id', how='inner')
moviebasics_ratings.head()
# Out:
#     movie_id                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres  averagerating  numvotes
# 0        2013            175.0    Action,Crime,Drama            7.0        77
# 1        2019            114.0       Biography,Drama            7.2        43
# 2        2018            122.0                 Drama            6.9      4517
# 3        2018             87.0          Comedy,Drama            6.1        13
# 4        2017             80.0  Comedy,Drama,Fantasy            6.5       119

# %%
#Let us investigate the type of genres that are there
unique_count(moviebasics_ratings['genres'])
# Out:
# array(['Action,Crime,Drama', 'Biography,Drama', 'Drama', 'Comedy,Drama',
#        'Comedy,Drama,Fantasy', 'Horror,Thriller',
#        'Adventure,Animation,Comedy', 'History', 'Documentary',
#        'Animation,Drama,History', 'Drama,Mystery',
#        'Action,Animation,Comedy', 'Crime,Drama', 'Biography,Comedy,Drama',
#        'Action,Drama', 'Documentary,History', 'Sci-Fi', 'Comedy',
#        'Thriller', 'Adventure,Animation,Sci-Fi', 'Drama,Horror',
#        'Drama,Mystery,Thriller', 'Drama,Family',
#        'Adventure,Comedy,Romance', 'Adventure,Drama,Romance',
#        'Comedy,Crime,Drama', 'Biography', 'Horror',
#        'Adventure,Comedy,Drama', 'Drama,Sci-Fi,Thriller', 'Action',
#        'Comedy,Drama,Romance', 'Action,Adventure,Sci-Fi', 'Comedy,Family',
#        'Adventure', 'Drama,History,War', 'Action,Thriller',
#        'Comedy,Crime', 'Crime,Drama,Thriller', 'Action,Sci-Fi,Thriller',
#        'Fantasy', 'Drama,Mystery,Sci-Fi', 'Biography,Drama,History',
# ...

# %% [markdown]
# There are a lot of genres but that is because each genre has different key genres, let us see if the list can be narrowed down

# %%
genres = unique_count(moviebasics_ratings['genres'])
unique_genres = set()
for genres_string in genres:
    genres_list = genres_string.split(',')
    unique_genres.update(genres_list)
unique_genres_string = ','.join(unique_genres)
print(unique_genres_string)
# Out:
# Adventure,Drama,Western,Horror,Animation,Short,Romance,Musical,News,War,Biography,Adult,Music,Sport,Sci-Fi,Fantasy,Thriller,Reality-TV,Game-Show,Documentary,Action,History,Comedy,Crime,Family,Mystery

# %% [markdown]
# That looks a bit more manageable. From the table I need to find out which of these unique genres appears the most

# %%
genres_list = []
for genres_string in genres:
    split = genres_string.split(',')
    genres_list.extend(split)
genre_counts = {}
for genre in genres_list:
    if genre in genre_counts:
        genre_counts[genre] += 1
    else:
        genre_counts[genre] = 1

# Find the most common genre and its count
for genre, count in genre_counts.items():
    print(f"{genre}: {count}")
# Out:
# Action: 153
# Crime: 116
# Drama: 215
# Biography: 95
# Comedy: 185
# Fantasy: 117
# Horror: 125
# Thriller: 127
# Adventure: 140
# Animation: 113
# History: 113
# Documentary: 173
# Mystery: 109
# Sci-Fi: 106
# Family: 121
# Romance: 122
# War: 64
# Music: 88
# Sport: 61
# Western: 65
# Musical: 79
# News: 34
# Reality-TV: 10
# Game-Show: 2
# Adult: 2
# Short: 1

# %% [markdown]
# Looks like Action appears the most

# %%
genre_counts = {
    'Action': 153,
    'Crime': 116,
    'Drama': 215,
    'Biography': 95,
    'Comedy': 185,
    'Fantasy': 117,
    'Horror': 125,
    'Thriller': 127,
    'Adventure': 140,
    'Animation': 113,
    'History': 113,
    'Documentary': 173,
    'Mystery': 109,
    'Sci-Fi': 106,
    'Family': 121,
    'Romance': 122,
    'War': 64,
    'Music': 88,
    'Sport': 61,
    'Western': 65,
    'Musical': 79,
    'News': 34,
    'Reality-TV': 10,
    'Game-Show': 2,
    'Adult': 2,
    'Short': 1
}
genres, counts = zip(*genre_counts.items())
c = ['red', 'yellow', 'black', 'blue', 'green']
plt.figure(figsize=(12, 6))
plt.bar(genres, counts, color = c)
plt.xlabel('Genres')
plt.ylabel('Counts')
plt.title('Genre Counts')
plt.xticks(rotation=90) 
plt.tight_layout();

# %%
value_count(moviebasics_ratings['genres'])
# Out:
# Drama                    11612
# Documentary              11117
# Comedy                    5613
# Horror                    2692
# Comedy,Drama              2617
#                          ...
# Crime,Western                1
# Action,Music                 1
# Adventure,Comedy,War         1
# Mystery,News,Thriller        1
# Action,Sport,Thriller        1
# Name: genres, Length: 923, dtype: int64

# %% [markdown]
# But most movies produced are in the Drama genre and the Documentary genre

# %%
#Let us see which type of movies have the highest ratings
moviebasics_ratingssorted = moviebasics_ratings.sort_values(by = 'averagerating', ascending=False)
moviebasics_ratingssorted.head()
# Out:
#         movie_id                                      primary_title  \
# 51109  tt5089804                    Fly High: Story of the Disc Dog
# 65944  tt7259300                                     Calamity Kevin
# 71577  tt8730716                      Pick It Up! - Ska in the '90s
# 73616  tt9715646                                           Renegade
# 65755  tt7227500  Ellis Island: The Making of a Master Race in A...
#
#                                           original_title  start_year  \
# 51109                    Fly High: Story of the Disc Dog        2019
# 65944                                     Calamity Kevin        2019
# 71577                      Pick It Up! - Ska in the '90s        2019
# 73616                                           Renegade        2019
# 65755  Ellis Island: The Making of a Master Race in A...        2018
#
#        runtime_minutes               genres  averagerating  numvotes
# 51109             65.0          Documentary           10.0         7
# ...

# %% [markdown]
# From the table the Documentary genre appears more than any other according to the average rating, which is how good the movie was given a rating by those who watched the movie and looking at the numvotes the number is not high

# %%
#Let us see which had the highest number of votes
moviebasics_numvotes = moviebasics_ratings.sort_values(by = 'numvotes',ascending=False)
moviebasics_numvotes.head(10)
# Out:
#         movie_id            primary_title           original_title  \
# 2387   tt1375666                Inception                Inception
# 2241   tt1345836    The Dark Knight Rises    The Dark Knight Rises
# 280    tt0816692             Interstellar             Interstellar
# 12072  tt1853728         Django Unchained         Django Unchained
# 325    tt0848228             The Avengers             The Avengers
# 507    tt0993846  The Wolf of Wall Street  The Wolf of Wall Street
# 1091   tt1130884           Shutter Island           Shutter Island
# 15327  tt2015381  Guardians of the Galaxy  Guardians of the Galaxy
# 2831   tt1431045                 Deadpool                 Deadpool
# 2523   tt1392170         The Hunger Games         The Hunger Games
#
#        start_year  runtime_minutes                   genres  averagerating  \
# 2387         2010            148.0  Action,Adventure,Sci-Fi            8.8
# 2241         2012            164.0          Action,Thriller            8.4
# ...

# %% [markdown]
# But according  to number of votes which is how popular the movie is, or in other words how people received the movie we have Action,Adventure,Sci-fi combination, the Action, Adventure combnation appears multiple times in the genres top 10

# %%
moviebasics_numvotes['numvotes']
# Out:
# 2387     1841066
# 2241     1387769
# 280      1299334
# 12072    1211405
# 325      1183655
#           ...
# 53263          5
# 62310          5
# 12881          5
# 6789           5
# 59062          5
# Name: numvotes, Length: 73856, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.bar(x=moviebasics_numvotes['genres'][:15], height=moviebasics_numvotes['numvotes'][:15], color = ['indigo'])
ax.set_xlabel('Genres')
ax.set_ylabel('Number of votes')
ax.set_title('Genre Number of votes')
plt.xticks(rotation=90);

# %% [markdown]
# From the top movie genre looks like most people enjoy the Action genre probably the reason why the Action genre is also the one that appears the most in all the genres from what we saw above.

# %% [markdown]
# ### RECOMMENDATIONS AND CONCLUSION
#
# From the analysis we investigated the most successful film, the most successful studio and why and the genre that resonates best with the audience.
#
# My recommendations are as follows:
#
# As you start the new movie studio from the analysis of the most successful film, The Avengers film is a good example of film to look at, with a bit of research I found that the storyline was what captivated the audience, and also after that the movies from that one, were also successful which we also saw in the Star Wars film. I would suggest once a film you produce is successful consider producing another film related to the first one if possible.
#
# From the analysis of the most successful studio and why it was successful I recommend producing as many movies as possible but also on the production budget, allocate enough money for the production of the film. As seen the production budget correlates highly with the profit made more than the number of movies made correlates with the total gross income. Focus on what is more important and here it is the production.
#
# From the analysis of genre, focus on movies with the genre type Drama, Action, Comedy as seen these were the best three genres and also the most produced, specifically also the Action, Adventure, Sci-Fi combination seems to appear a lot.

# %% [markdown]
# There is always more data to explore.
# The data on revenue from streaming services would have been of great help to find out what streaming service is better and gets you the most revenue which I lacked in this analysis.

# %% [markdown]
# I conclude by saying that the content production field can be both successful and a failure but taking time to learn about your market through research is definetly a step in the right direction.
